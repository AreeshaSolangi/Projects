# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ABC\Documents\data Analytics completed projects\Projects\Task 2 Exploratory Data Analysis on Titanic Dataset\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.rename(columns={"Sex": "Gender"}, inplace=True)

# %% [markdown]
# ### how many nulls in age?

# %%
df["Age"].isna().sum()
# Out:
# 177

# %%
### Remove Nulls if any

# %% [markdown]
# ### what percentage of all columns are null?

# %%
df.duplicated().sum()
# Out:
# 0

# %%
nullcol=df.isna().sum()/len(df)*100
sns.pointplot(nullcol)
plt.xticks(rotation=90)
plt.title("% of Null columns");

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - we can drop or ignore the cabin column because above 70% records are null
# -  In my case i will just ignore it incase i find come insights
# -   Age column have some nulls we will try to fix them

# %% [markdown]
# ### Pclass calues
# - 1->Upper Class
# - 2->Middle Class
# - 3->Lower Class

# %%
classs={1:"Upper Class",2:"Middle Class", 3: "Lower Class"}
df["Pclass"]=df["Pclass"].map(classs)
df
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Lower Class
# 1              2         1   Upper Class
# 2              3         1   Lower Class
# 3              4         1   Upper Class
# 4              5         0   Lower Class
# ..           ...       ...           ...
# 886          887         0  Middle Class
# 887          888         1   Upper Class
# 888          889         0   Lower Class
# 889          890         1   Upper Class
# 890          891         0   Lower Class
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
classs={"C":"Cherbourg","S":"Southampton", "Q": "Queenstown"}
df["Embarked"]=df["Embarked"].map(classs)
df
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Lower Class
# 1              2         1   Upper Class
# 2              3         1   Lower Class
# 3              4         1   Upper Class
# 4              5         0   Lower Class
# ..           ...       ...           ...
# 886          887         0  Middle Class
# 887          888         1   Upper Class
# 888          889         0   Lower Class
# 889          890         1   Upper Class
# 890          891         0   Lower Class
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## Explore Age

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %%
sns.histplot(df["Age"])
plt.title("Age Distrinution")
# Out:
# Text(0.5, 1.0, 'Age Distrinution')

# %%
df["Age"].isna().sum()
# Out:
# 177

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## handle Age column
# - I will not delete nulls in the age column because it would delete 20% data which is huge
# - since sknew is near 0 and mean, 50% percentile arent too far I will probably replace data with mean
# - replacing 20% data with mean wont be bias

# %%
df["Age"]=df.groupby("Gender")["Age"].transform(lambda x: x.fillna(x.mean()))
df["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    27.915709
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]=df["Age"].astype(int)

# %% [markdown]
# ### clean Ticket Column

# %%
df["Ticket"]
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df["Ticket"]=df["Ticket"].str.split(" ").str.get(-1)

# %%
df
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Lower Class
# 1              2         1   Upper Class
# 2              3         1   Lower Class
# 3              4         1   Upper Class
# 4              5         0   Lower Class
# ..           ...       ...           ...
# 886          887         0  Middle Class
# 887          888         1   Upper Class
# 888          889         0   Lower Class
# 889          890         1   Upper Class
# 890          891         0   Lower Class
#
#                                                   Name  Gender  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ...

# %%
df["Embarked"]=df["Embarked"].fillna(df["Embarked"].mode())

# %% [markdown]
# - Since Embarked Column has 2 nulls only so we replaced it with mode/ most frequent value

# %%
df["Fare"].skew()
# Out:
# 4.787316519674893

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838   29.564534    0.523008    0.381594   32.204208
# std     257.353842    0.486592   13.027414    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000   30.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.histplot(df["Fare"])
plt.title("Fare Distribution");
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# - fare has high skew 4
# - fare mean and 50th percentile have a huge difference mean is 32 50th is 14
# - valuea are not normally distriuted so we will use logarithmic transformation to reduce the skewness

# %%
df["Fare"]=np.log1p(df["Fare"])

# %%
sns.histplot(df["Fare"])
plt.title("Fare Distribution");

# %%
df["Fare"].skew()
# Out:
# 0.3949280095189306

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.564534    0.523008
# std     257.353842    0.486592    0.836071   13.027414    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   30.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594    2.962246
# std      0.806057    0.969048
# min      0.000000    0.000000
# 25%      0.000000    2.187218
# 50%      0.000000    2.737881
# 75%      0.000000    3.465736
# max      6.000000    6.240917

# %% [markdown]
# - we fixed fair values mean and 50% valuea arent too far and values are normally distributed

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# ### Creating Bins for age and Fare for better analysis

# %%
df["Fare_bin"]=pd.qcut(df["Fare"], q=4, labels=["Low","Medium","High","Very High"])

# %%
df["Age_bin"] = pd.cut(
    df["Age"], 
    bins=[0, 12, 18, 30, 45, 60, 80],  # 6 intervals
    labels=["Child", "Teen", "Young Adult", "Adult", "Middle Aged", "Senior"]
)

# %%
df
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Lower Class
# 1              2         1   Upper Class
# 2              3         1   Lower Class
# 3              4         1   Upper Class
# 4              5         0   Lower Class
# ..           ...       ...           ...
# 886          887         0  Middle Class
# 887          888         1   Upper Class
# 888          889         0   Lower Class
# 889          890         1   Upper Class
# 890          891         0   Lower Class
#
#                                                   Name  Gender  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ...

# %% [markdown]
# # Univariate Analysis

# %%
fig, axes= plt.subplots(3,3, figsize=(12,12))
axes=axes.ravel()
for i, predictor in enumerate(df.drop(columns=["Survived","Cabin","Fare","Ticket","Age","Name","PassengerId"])):
    sns.countplot(data=df, x=predictor, hue="Survived", ax=axes[i])
    plt.tight_layout()
    axes[i].legend(["Not Survived","Survived"])
    axes[i].set_title(f"Survival vs {predictor}")
axes[6].tick_params(axis='x', rotation=90);

# %% [markdown]
# ### Insights From Univariate Analysis survival vs Individual Features
# - Class: Upper class survived more, lower class less.
# - Gender: Females survived more than males.
# - Embarked: Cherbourg passengers survived more, Southampton less.
# - Fare: Higher fare → higher survival.
# - Age: Children/teens survived more, adults/seniors less.

# %% [markdown]
# # Bivariate Analysis

# %%
mth=sns.kdeplot(df["Age"][(df["Survived"]==1)], color="green", fill=True)
mth=sns.kdeplot(df["Age"][(df["Survived"]==0)], color="red", fill=True)
mth.legend(["Not Survived","Survived"])
plt.title("Survival count by Age")
# Out:
# Text(0.5, 1.0, 'Survival count by Age')

# %%
mth=sns.kdeplot(df["Fare"][(df["Survived"]==1)], color="green", fill=True)
mth=sns.kdeplot(df["Fare"][(df["Survived"]==0)], color="red", fill=True)
mth.legend(["Not Survived","Survived"])
plt.title("Survival count by Fare")
# Out:
# Text(0.5, 1.0, 'Survival count by Fare')

# %% [markdown]
# # Multivariate Analysis

# %%
sns.scatterplot(data=df, x="Fare",y="Age", hue="Survived", palette={0: "red",1:"green"}, alpha=0.7)

plt.title("Fare vs Age by Survival")
# Out:
# Text(0.5, 1.0, 'Fare vs Age by Survival')

# %%
sns.catplot(df,x="Gender", y="Age", hue="Survived", kind="box", palette={1:"green",0:"red"})
plt.title("Gender vs Age by Survival")
# Out:
# Text(0.5, 1.0, 'Gender vs Age by Survival')

# %% [markdown]
# # Numerical Analysis
# - Find Correlation between values
# - with describe Show Statistical Summary

# %%
sns.heatmap(df.select_dtypes(include=("number")).corr())
plt.title("Heatmap of Survival Correlations")
# Out:
# Text(0.5, 1.0, 'Heatmap of Survival Correlations')

# %%
df2=pd.get_dummies(df.drop(columns=["PassengerId","Name","Ticket","Cabin","Fare","Age"]), dtype=int)

# %%
corr=df2.corr()["Survived"].sort_values()
corr.plot(kind="bar", figsize=(12,5))
plt.title("Correlation of Survival with different features")
# Out:
# Text(0.5, 1.0, 'Correlation of Survival with different features')

# %%
corr_df=corr.reset_index()
corr_df[(corr_df["Survived"]>0.2) | (corr_df["Survived"]<-0.2)]
# Out:
#                  index  Survived
# 0          Gender_male -0.543351
# 1   Pclass_Lower Class -0.322308
# 2         Fare_bin_Low -0.221610
# 17  Fare_bin_Very High  0.233638
# 18  Pclass_Upper Class  0.285904
# 19       Gender_female  0.543351
# 20            Survived  1.000000

# %% [markdown]
# ## keeping -2 and 2 My Threshold
# - male, lower class ticket and low fare have negative correlation with survival
# - Female, upper class ticket and high fare have positive correlation with survival

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838   29.564534    0.523008    0.381594    2.962246
# std     257.353842    0.486592   13.027414    1.102743    0.806057    0.969048
# min       1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000   22.000000    0.000000    0.000000    2.187218
# 50%     446.000000    0.000000   30.000000    0.000000    0.000000    2.737881
# 75%     668.500000    1.000000   35.000000    1.000000    0.000000    3.465736
# max     891.000000    1.000000   80.000000    8.000000    6.000000    6.240917

# %% [markdown]
# ## Conclusion : Some quick Insigts
#  - Women had a higher chance of survival compared to men.
#  - Children survived more often than older passengers.
#  - Passengers who paid higher fares (mostly first class) had better chances of survival.
#  - People boarding from Cherbourg had higher survival rates than those from Southampton or Queenstown.
